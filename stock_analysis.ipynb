# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

def get_stock_info(ticker):
    stock = yf.Ticker(ticker)
    info = stock.info
    company_info = {
        "Название компании": info.get('longName', 'N/A'),
        "Рыночная капитализация": info.get('marketCap', 'N/A'),
        "P/E коэффициент": info.get('trailingPE', 'N/A'),
        "Цена акции": info.get('regularMarketPrice', 'N/A'),
        "Доходность дивидендов": info.get('dividenYeld', 'N/A')

    }
    return company_info

# %%
ticker = 'AAPL'
info = get_stock_info(ticker)
print(info)
# Out:
# {'Название компании': 'Apple Inc.', 'Рыночная капитализация': 3458416246784, 'P/E коэффициент': 37.88797, 'Цена акции': 'торги не проводятся', 'Доходность дивидендов': 'N/A'}

# %% [markdown]
# Получение исторических данных

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

def get_history_data(ticker, period):
    stock = yf.Ticker(ticker)
    data = stock.history(period=period)
    return data

def plot_price_trend(data, ticker):
    plt.figure(figsize=(10, 6))
    data['Close'].plot(label='Цена закрытия', color='blue')
    plt.title(f'График цены акции {ticker}')
    plt.xlabel('Дата')
    plt.ylabel('Цена (USD)')
    plt.legend()
    return plt

# %%
stock = yf.Ticker('AAPL')
data = stock.history(period='1mo')

plot_price_trend(data, 'AAPL')

plt.show()
